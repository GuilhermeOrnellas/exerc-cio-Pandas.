# %% [markdown]
# <a href="https://colab.research.google.com/github/GuilhermeOrnellas/exerc-cio-Pandas./blob/main/folium.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# geração de dados

# %%
import pandas as pd
import numpy as np
import folium
from folium.plugins import MarkerCluster

np.random.seed(42)
n_imoveis = 45

dados_imoveis = {
    'id_imovel': range(1, n_imoveis + 1),
    'cidade': np.where(
        np.random.rand(n_imoveis) > 0.4,
        'Nova Iguaçu',
        'Queimados'
    ),
    'valor_venda': np.random.uniform(
        150000,
        850000,
        n_imoveis
    ).round(2),
    'tipo': np.random.choice(
        ['Casa', 'Apartamento', 'Terreno'],
        n_imoveis
    )
}

df_mapa = pd.DataFrame(dados_imoveis)


def gerar_lat(cidade):
    if cidade == 'Nova Iguaçu':
        return -22.756 + np.random.uniform(-0.03, 0.03)
    return -22.716 + np.random.uniform(-0.02, 0.02)


def gerar_lon(cidade):
    if cidade == 'Nova Iguaçu':
        return -43.460 + np.random.uniform(-0.03, 0.03)
    return -43.555 + np.random.uniform(-0.02, 0.02)


df_mapa['latitude'] = df_mapa['cidade'].apply(gerar_lat)
df_mapa['longitude'] = df_mapa['cidade'].apply(gerar_lon)

# %% [markdown]
# parte 1

# %%
latitude_media = df_mapa['latitude'].mean()
longitude_media = df_mapa['longitude'].mean()

mapa_basico = folium.Map(
    location=[latitude_media, longitude_media],
    zoom_start=12,
    tiles='OpenStreetMap'
)

for _, imovel in df_mapa.head(5).iterrows():

    popup_texto = (
        f"<b>Tipo:</b> {imovel['tipo']}<br>"
        f"<b>Valor de venda:</b> R$ {imovel['valor_venda']:,.2f}"
    )

    folium.Marker(
        location=[
            imovel['latitude'],
            imovel['longitude']
        ],
        popup=popup_texto
    ).add_to(mapa_basico)

mapa_basico
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_0424d5a4bee7c9ba43b546129566e11e {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_0424d5a4bee7c9ba43b546129566e11e&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_0424d5a4bee7c9ba43b546129566e11e = L.map(
#                 &quot;map_0424d5a4bee7c9ba43b546129566e11e&quot;,
#                 {
#                     center: [-22.736785025907697, -43.50738358758272],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 12,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_f9aea89c9906eab4ee611a178e17fec0 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_f9aea89c9906eab4ee611a178e17fec0.addTo(map_0424d5a4bee7c9ba43b546129566e11e);
#
#
#             var marker_3429db457d593a6904d210bf7185bc04 = L.marker(
#                 [-22.714426310323375, -43.57138840919782],
#                 {
# }
#             ).addTo(map_0424d5a4bee7c9ba43b546129566e11e);
#
#
#         var popup_ec0032972fcf974e4094937e1197f7e1 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_3519993246ec6ee553c86ebf785eb640 = $(`&lt;div id=&quot;html_3519993246ec6ee553c86ebf785eb640&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;b&gt;Tipo:&lt;/b&gt; Casa&lt;br&gt;&lt;b&gt;Valor de venda:&lt;/b&gt; R$ 613,765.60&lt;/div&gt;`)[0];
#                 popup_ec0032972fcf974e4094937e1197f7e1.setContent(html_3519993246ec6ee553c86ebf785eb640);
#
#
#
#         marker_3429db457d593a6904d210bf7185bc04.bindPopup(popup_ec0032972fcf974e4094937e1197f7e1)
#         ;
#
#
#
#
#             var marker_067bf0fddf3101969a11331a49416587 = L.marker(
#                 [-22.73755359069016, -43.43988185026465],
#                 {
# }
#             ).addTo(map_0424d5a4bee7c9ba43b546129566e11e);
#
#
#         var popup_ed63678da69221da0b616169099fcad1 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_d1869c3b68c4586403607cc7d85e0b93 = $(`&lt;div id=&quot;html_d1869c3b68c4586403607cc7d85e0b93&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;b&gt;Tipo:&lt;/b&gt; Terreno&lt;br&gt;&lt;b&gt;Valor de venda:&lt;/b&gt; R$ 368,197.75&lt;/div&gt;`)[0];
#                 popup_ed63678da69221da0b616169099fcad1.setContent(html_d1869c3b68c4586403607cc7d85e0b93);
#
#
#
#         marker_067bf0fddf3101969a11331a49416587.bindPopup(popup_ed63678da69221da0b616169099fcad1)
#         ;
#
#
#
#
#             var marker_d666934cea7536506d464940c60c418f = L.marker(
#                 [-22.73223452200459, -43.4707531961017],
#                 {
# }
#             ).addTo(map_0424d5a4bee7c9ba43b546129566e11e);
#
#
#         var popup_59dc9528d31c30f7bef307015294583d = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_21f882a7246965faf9d0eccd1c4a4b9f = $(`&lt;div id=&quot;html_21f882a7246965faf9d0eccd1c4a4b9f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;b&gt;Tipo:&lt;/b&gt; Apartamento&lt;br&gt;&lt;b&gt;Valor de venda:&lt;/b&gt; R$ 514,047.61&lt;/div&gt;`)[0];
#                 popup_59dc9528d31c30f7bef307015294583d.setContent(html_21f882a7246965faf9d0eccd1c4a4b9f);
#
#
#
#         marker_d666934cea7536506d464940c60c418f.bindPopup(popup_59dc9528d31c30f7bef307015294583d)
#         ;
#
#
#
#
#             var marker_0b54318fc93739e4ddb2fa4c75446c49 = L.marker(
#                 [-22.76691979150169, -43.47880888937601],
#                 {
# }
#             ).addTo(map_0424d5a4bee7c9ba43b546129566e11e);
#
#
#         var popup_165e6905978f921a894e7e0d2eb6d6de = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_2c9f2459266f03d38fbe6e21e2d86129 = $(`&lt;div id=&quot;html_2c9f2459266f03d38fbe6e21e2d86129&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;b&gt;Tipo:&lt;/b&gt; Terreno&lt;br&gt;&lt;b&gt;Valor de venda:&lt;/b&gt; R$ 532,697.20&lt;/div&gt;`)[0];
#                 popup_165e6905978f921a894e7e0d2eb6d6de.setContent(html_2c9f2459266f03d38fbe6e21e2d86129);
#
#
#
#         marker_0b54318fc93739e4ddb2fa4c75446c49.bindPopup(popup_165e6905978f921a894e7e0d2eb6d6de)
#         ;
#
#
#
#
#             var marker_2f5c83338f255d15ee72a392cc03a0b6 = L.marker(
#                 [-22.731597923018892, -43.57336899433781],
#                 {
# }
#             ).addTo(map_0424d5a4bee7c9ba43b546129566e11e);
#
#
#         var popup_0c919b9249b570ea878bb92a8a9b5b9b = L.popup({
#   &

# %% [markdown]
# parte 2

# %%
mapa_circulos = folium.Map(
    location=[latitude_media, longitude_media],
    zoom_start=12,
    tiles='OpenStreetMap'
)

for _, imovel in df_mapa.iterrows():

    if imovel['cidade'] == 'Nova Iguaçu':
        cor = 'blue'
    else:
        cor = 'orange'

    popup_texto = (
        f"<b>ID:</b> {imovel['id_imovel']}<br>"
        f"<b>Cidade:</b> {imovel['cidade']}<br>"
        f"<b>Tipo:</b> {imovel['tipo']}<br>"
        f"<b>Valor:</b> R$ {imovel['valor_venda']:,.2f}"
    )

    folium.CircleMarker(
        location=[
            imovel['latitude'],
            imovel['longitude']
        ],
        radius=8,
        color=cor,
        fill=True,
        fill_color=cor,
        fill_opacity=0.7,
        tooltip='Clique para detalhes',
        popup=popup_texto
    ).add_to(mapa_circulos)

mapa_circulos
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_1213f1adea0f6bf8b95cba4b9e8d71ee {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_1213f1adea0f6bf8b95cba4b9e8d71ee&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_1213f1adea0f6bf8b95cba4b9e8d71ee = L.map(
#                 &quot;map_1213f1adea0f6bf8b95cba4b9e8d71ee&quot;,
#                 {
#                     center: [-22.736785025907697, -43.50738358758272],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 12,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_137fd5067f091f5762274dd28db8069a = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_137fd5067f091f5762274dd28db8069a.addTo(map_1213f1adea0f6bf8b95cba4b9e8d71ee);
#
#
#             var circle_marker_b83ce6217927618158cb4309d9b460db = L.circleMarker(
#                 [-22.714426310323375, -43.57138840919782],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;orange&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;orange&quot;, &quot;fillOpacity&quot;: 0.7, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 8, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_1213f1adea0f6bf8b95cba4b9e8d71ee);
#
#
#         var popup_955415cd9dd978b1de85824e750cfad4 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_a6f185bc313f04e6ad2396000411cb70 = $(`&lt;div id=&quot;html_a6f185bc313f04e6ad2396000411cb70&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;b&gt;ID:&lt;/b&gt; 1&lt;br&gt;&lt;b&gt;Cidade:&lt;/b&gt; Queimados&lt;br&gt;&lt;b&gt;Tipo:&lt;/b&gt; Casa&lt;br&gt;&lt;b&gt;Valor:&lt;/b&gt; R$ 613,765.60&lt;/div&gt;`)[0];
#                 popup_955415cd9dd978b1de85824e750cfad4.setContent(html_a6f185bc313f04e6ad2396000411cb70);
#
#
#
#         circle_marker_b83ce6217927618158cb4309d9b460db.bindPopup(popup_955415cd9dd978b1de85824e750cfad4)
#         ;
#
#
#
#
#             circle_marker_b83ce6217927618158cb4309d9b460db.bindTooltip(
#                 `&lt;div&gt;
#                      Clique para detalhes
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#             var circle_marker_ce7730294ea360f8581e6fb1de63a886 = L.circleMarker(
#                 [-22.73755359069016, -43.43988185026465],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.7, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 8, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_1213f1adea0f6bf8b95cba4b9e8d71ee);
#
#
#         var popup_a044a37b4d1ff919aa5bbc28361dfb38 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_14accd56d5f1a633c2e77068eb90b0de = $(`&lt;div id=&quot;html_14accd56d5f1a633c2e77068eb90b0de&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;b&gt;ID:&lt;/b&gt; 2&lt;br&gt;&lt;b&gt;Cidade:&lt;/b&gt; Nova Iguaçu&lt;br&gt;&lt;b&gt;Tipo:&lt;/b&gt; Terreno&lt;br&gt;&lt;b&gt;Valor:&lt;/b&gt; R$ 368,197.75&lt;/div&gt;`)[0];
#                 popup_a044a37b4d1ff919aa5bbc28361dfb38.setContent(html_14accd56d5f1a633c2e77068eb90b0de);
#
#
#
#         circle_marker_ce7730294ea360f8581e6fb1de63a886.bindPopup(popup_a044a37b4d1ff919aa5bbc28361dfb38)
#         ;
#
#
#
#
#             circle_marker_ce7730294ea360f8581e6fb1de63a886.bindTooltip(
#                 `&lt;div&gt;
#                      Clique para detalhes
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#             var circle_marker_5d7d5fae7339c31772decb2abe94d14a = L.circleMarker(
#                 [-22.73223452200459, -43.4707531961017],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.7, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&qu

# %% [markdown]
# parte 3

# %%
mapa_cluster = folium.Map(
    location=[latitude_media, longitude_media],
    zoom_start=12,
    tiles='OpenStreetMap'
)

cluster = MarkerCluster()
cluster.add_to(mapa_cluster)

cores_tipo = {
    'Casa': 'green',
    'Apartamento': 'blue',
    'Terreno': 'gray'
}

for _, imovel in df_mapa.iterrows():

    cor = cores_tipo[imovel['tipo']]

    popup_texto = (
        f"<b>ID do imóvel:</b> {imovel['id_imovel']}<br>"
        f"<b>Cidade:</b> {imovel['cidade']}<br>"
        f"<b>Tipo:</b> {imovel['tipo']}<br>"
        f"<b>Valor de venda:</b> "
        f"R$ {imovel['valor_venda']:,.2f}"
    )

    marcador = folium.Marker(
        location=[
            imovel['latitude'],
            imovel['longitude']
        ],
        popup=popup_texto,
        tooltip='Clique para detalhes',
        icon=folium.Icon(
            color=cor,
            icon='home',
            prefix='fa'
        )
    )

    marcador.add_to(cluster)

# %% [markdown]
# salvar

# %%
mapa_cluster.save('mapa_imoveis_baixada.html')

print('Mapa final salvo com sucesso!')
print('Arquivo: mapa_imoveis_baixada.html')
# Out:
# Mapa final salvo com sucesso!
# Arquivo: mapa_imoveis_baixada.html
