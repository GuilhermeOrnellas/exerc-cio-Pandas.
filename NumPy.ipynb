# %% [markdown]
# <a href="https://colab.research.google.com/github/GuilhermeOrnellas/exerc-cio-Pandas./blob/main/NumPy.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Modulo 1 (nível 1, 2 e 3)

# %%
import numpy as np

pecas_vendidas = np.array([150, 120, 90, 210, 300, 250, 180])
faturamento = pecas_vendidas * 50
dias_pico = pecas_vendidas[pecas_vendidas > 200]

loja_a = [200, 220, np.nan, 250]
loja_b = [150, 180, 160, 190]
loja_c = [300, 310, 290, 330]

matriz_lojas = np.array([loja_a, loja_b, loja_c])
total_por_loja = np.nansum(matriz_lojas, axis=1)
media_diaria_rede = np.nanmean(matriz_lojas)
status_meta = np.where(matriz_lojas >= 200, 'Meta Atingida', 'Abaixo')

rng = np.random.default_rng(seed=42)
categorias = np.array(['Eletrônicos', 'Roupas', 'Casa'])
amostra_vendas = rng.choice(categorias, size=50)

valores, contagens = np.unique(amostra_vendas, return_counts=True)
volume_vendas = dict(zip(valores, contagens))

faturamento_campanhas = np.array([12000, 45000, 23000, 89000, 31000])
indice_campeao = np.argmax(faturamento_campanhas)

# %% [markdown]
# Modulo 2 (nível 1, 2 e 3)

# %%
import numpy as np

dias_mes = np.arange(1, 31)
metas_semana = np.linspace(20000, 30000, 5)
estoque_decimal = np.array([10.5, 20.1, 30.9])
estoque_inteiro = estoque_decimal.astype(int)
ultimos_5_dias_invertidos = dias_mes[-5:][::-1]

visitas_12_meses = np.array([100, 120, 130, 110, 140, 150, 160, 170, 180, 190, 200, 210])
matriz_trimestres = visitas_12_meses.reshape(4, 3)

semestre_1 = np.array([[10, 20, 30], [40, 50, 60]])
semestre_2 = np.array([[70, 80, 90], [100, 110, 120]])
ano_completo = np.vstack((semestre_1, semestre_2))

primeiro_trimestre_copia = matriz_trimestres[0, :].copy()
relatorio_corrido = matriz_trimestres.ravel()

pontuacoes = np.array([85, 92, 78, 95, 88])
indices_ordenados = np.argsort(pontuacoes)

precos_base = np.array([100, 200, 300])
precos_coluna = precos_base[:, np.newaxis]
descontos = np.array([0.9, 0.8, 0.7])
matriz_precos_com_desconto = precos_coluna * descontos

A = np.array([[2, 1], [1, -1]])
b = np.array([500, 100])
custos_unitarios = np.linalg.solve(A, b)
